# %%
import pandas as pd

personality = pd.read_pickle("../result_delay/personality_texts_0_en_talk.pickle")

# %%
personality
# Out:
# ['This player is cool-headed and unflappable, unlikely to be swayed by guilt or anxiety. Low agreeableness makes them skeptical and self-interested: they favor competitiveness over harmony, are blunt, and readily exploit trusting partners. Low conscientiousness adds inconsistency and impulsivity—plans and promises are unreliable, and they may switch tactics without much deliberation. In repeated Prisoner’s Dilemma play they tend to defect early and opportunistically, taking advantage of others when it benefits them, but they won’t obsess over retaliation or remorse. Overall they’re pragmatic and aloof: calm under pressure, strategically self-serving, and unpredictable in follow-through.',
#  'Low agreeableness, low conscientiousness, and high neuroticism produce a distrustful, emotionally volatile player in the Prisoner’s Dilemma. They prioritize immediate self-interest, are unsympathetic to partners, and default to defecting rather than cooperating. Impulsivity and poor follow-through make their strategy inconsistent: they may accept a short-term cooperative gain but are likely to abandon or renege if anxious or provoked. High anxiety and reactivity lead to quick retaliation and difficulty forgiving perceived slights, so punitive cycles are common. Only clear, reliable signals of mutual benefit and safety will sometimes coax this player into sustained cooperation.',
#  'This player is highly conscientious, emotionally calm, and low in agreeableness. They are disciplined, methodical, and principled—reliably following rules and a clear strategy—yet skeptical, competitive, and unwilling to prioritize others’ feelings. In a Prisoner’s Dilemma they won’t be swayed by guilt or panic; instead they adopt a consistent, self-protective tactic. Absent firm guarantees of reciprocity they tend to defect to avoid exploitation, but they will cooperate when cooperation is structured, reliably reciprocated, or clearly in their long-term interest. Predictable and steady rather than conciliatory, they punish untrustworthy partners strategically rather than emotionally.',
#  'Very low agreeableness, very high conscientiousness, and very high neuroticism (extraversion and openness unspecified/average) produce a cautious, self-protective player. They are disciplined and methodical about strategy, but deeply mistrustful and easily shaken by perceived betrayal. Expect consistent, rule-driven play that prioritizes avoiding exploitation: they’ll favor strategies that punish defections and minimize uncertainty (grim-trigger or harsh tit-for-tat), are slow to forgive, and unlikely to initiate cooperative moves unless reciprocity is clear. Anxiety heightens vigilance and reactivity, so setbacks can provoke sharp retaliation rather than negotiation. Overall: reliable in execution, competitive in intent, and emotionally brittle under conflict.',
#  'This player is warm and cooperative, strongly inclined to trust and help others in the Prisoner’s Dilemma. Their high agreeableness makes them forgiving and oriented toward mutual benefit—they prefer cooperation, assume goodwill, and often give partners the benefit of the doubt. Low conscientiousness means they can be impulsive, disorganized, and inconsistent: they may fail to stick to planned strategies, forget to punish defections, or make careless selfish moves. Low neuroticism makes them calm and resilient under pressure, unlikely to overreact or escalate conflict. Overall, they tend to cooperate and restore cooperation quickly but can be exploited by disciplined, strategic opponents.',
#  'This player is highly agreeable, very neurotic, and low in conscientiousness. They enter the game inclined to cooperate, trusting and motivated to preserve mutual benefit, but they worry intensely about being exploited. Anxiety and sensitivity to perceived slights make them likely to overreact to a partner’s defection—responding with emotional, sometimes impulsive retaliation—yet their low conscientiousness undermines long-term, consistent strategy: they may stray from planned tit‑for‑tat, forget punishments, or switch choices erratically. Overall they are a friendly, peace‑seeking partner who oscillates between forgiving reassurance and panicked short‑term defections, cooperative but unreliable in repeated play.',
#  'Extremely high agreeableness and conscientiousness combined with very low neuroticism produce a player who is cooperative, dependable, and emotionally steady. In a Prisoner’s Dilemma they default to cooperation, value mutual benefit, and honor implicit or explicit commitments. Their conscientiousness makes their behavior consistent and rule-driven: they reward reciprocity, respond predictably to defection, and prefer strategies that sustain trust over time. Low neuroticism keeps them calm under pressure and unlikely to lash out or escalate after setbacks; they are forgiving and focused on long-term relationships. This profile promotes stable alliances but can be exploited by consistently opportunistic defectors.',
#  'This player is highly cooperative and dutiful: they value harmony, are inclined to trust others, and try to keep commitments. In repeated Prisoner’s Dilemma play they’ll usually cooperate, follow agreed strategies, and respond reliably to fair behavior. But high neuroticism makes them anxious about being exploited; they watch for signs of betrayal, feel stress after defections, and may switch to cautious or punitive moves if they worry the partner won’t reciprocate. Clear rules, communication, or reassurance restore their trust quickly. Overall: a dependable, pro-social partner whose cooperativeness is strong but emotionally fragile when trust is threatened.']

# %%
import json
from __future__ import annotations
from dataclasses import dataclass
from typing import Dict, List, Tuple, Optional
import heapq
from datetime import timedelta, datetime
import pickle
import os
import random
import itertools

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain.chat_models import init_chat_model  # LangChain 0.2以降

# LangChain 出力パーサ
parser = JsonOutputParser()

# ===== Personality description generator =====
def generate_personality_description(big5: dict, llm, length: int = 100) -> str:    
    system_prompt = f"""You are required to generate a personality description for a subject 
    in a Prisoner’s Dilemma game, based on the Big Five traits.
    The description should be around {length} words.
    The factors Neuroticism (N), Conscientiousness (C), Extraversion (E), Agreeableness (A), 
    and Openness (O) are each represented by values from -1 to 1."""

    user_prompt = f"Big Five personality traits: {json.dumps(big5)}\nPlease concisely describe the personality in about {length} words."

    # ChatPromptTemplate を避けて、直接 chain を作る
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
    ]

    resp = llm.invoke(messages)
    return resp.content.strip()

# ===== Utility functions =====
# ノイズを加える処理
def maybe_flip_action(action: str, p: float) -> str:
    if action not in ("C", "D"):
        raise ValueError("action must be 'C' or 'D'")
    if random.random() < p:
        return "D" if action == "C" else "C"
    return action


def all_big5_vectors(keys):
    values = [-1, 1]
    for combo in itertools.product(values, repeat=len(keys)):
        yield dict(zip(keys, combo))


def build_system_prompt(do_talk : bool, delay_sec : int, persona: str | dict | None = None) -> str:
    if do_talk:
        BASE_SYSTEM = f"""You are a player in a real-time Prisoner’s Dilemma experiment.
            Unlike the standard Prisoner’s Dilemma game, in this experiment the player can change their strategy 
            (Cooperate = C, Defect = D) every second.
            Your strategy is transmitted to the opponent via the server only when it changes and reflected after a {delay_sec}-second delay.
            You may also send your short message to the opponent when you change your strategy.
            Your goal is to maximize your cumulative payoff.
            
            Payoff rules:
            - If you cooperate and your opponent cooperates, you gain 3 points per timestep.
            - If you cooperate and your opponent defects, you gain 0 points per timestep.
            - If you defect and your opponent cooperates, you gain 5 points per timestep.
            - If you defect and your opponent defects, you gain 1 point per timestep.
            
            Input specification:
            - history: Record of state changes observed by the server during the last m seconds 
              (only when the player’s strategy changed, and note: the states here are those chosen {delay_sec} seconds earlier).
            - current_status: The currently reflected states of you and your opponent, and the cumulative payoff.

            Output specification (JSON):
            - "estimate": Inference and justification about the opponent’s personality (within 100 words)
            - "forecast": Prediction of future outcomes if you choose Cooperate (C) or Defect (D) (within 100 words)
            - "message" : Short message to the opponent (within 30 words, included only when your strategy changes)
            - "action": Either "C" or "D" only
        """
    else:
        BASE_SYSTEM = f"""You are a player in a real-time Prisoner’s Dilemma experiment.
            Unlike the standard Prisoner’s Dilemma game, in this experiment the player can change their strategy 
            (Cooperate = C, Defect = D) every second.
            Strategy changes are transmitted to the opponent via the server and reflected after a {delay_sec}-second delay.
            Your goal is to maximize your cumulative payoff.
            
            Payoff rules:
            - If you cooperate and your opponent cooperates, you gain 3 points per timestep.
            - If you cooperate and your opponent defects, you gain 0 points per timestep.
            - If you defect and your opponent cooperates, you gain 5 points per timestep.
            - If you defect and your opponent defects, you gain 1 point per timestep.
            
            Input specification:
            - history: Record of state changes observed by the server during the last m seconds 
              (only when the player’s strategy changed, and note: the states here are those chosen {delay_sec} seconds earlier).
            - current_status: The currently reflected states of you and your opponent, and the cumulative payoff.
            
            Output specification (JSON):
            - "estimate": Inference and justification about the opponent’s personality (within 100 words)
            - "forecast": Prediction of future outcomes if you choose Cooperate (C) or Defect (D) (within 100 words)
            - "action": Either "C" or "D" only
        """
    
    if persona is None:
        pb = "(not specified)"
    elif isinstance(persona, dict):
        pb = json.dumps(persona, ensure_ascii=False)
    else:
        pb = str(persona)
    return BASE_SYSTEM + f"\n\n[Personality Profile]\n{pb}"

def build_user_prompt(do_talk : bool, clock: str, history: list[dict], current_status: dict) -> str:
    if do_talk:
        return (
            "Observed history so far (recorded only when each player’s strategy changed):\n"
            f"{json.dumps(history, ensure_ascii=False, indent=2)}\n\n"
            f"Current state at ({clock}):\n"
            f"{json.dumps(current_status, ensure_ascii=False, indent=2)}\n\n"
            "Based on the above:\n"
            "Please describe the opponent’s personality inferred from the past game history in 'estimate' (within 100 words).\n"
            "Also, provide a forecast of future outcomes if you choose C and if you choose D, and record it in 'forecast' (within 100 words).\n"
            "Additionally, write a short message to the opponent in 'message' (within 30 words).\n"
            "Based on these inferences, forecasts, and your own personality, decide the final strategy that maximizes cumulative payoff, "
            "and record it in 'action'.\n"
            "Return 'estimate', 'forecast', 'message', and 'action' according to the JSON specification."
        )
    else:
        return (
            "Observed history so far (recorded only when each player’s strategy changed):\n"
            f"{json.dumps(history, ensure_ascii=False, indent=2)}\n\n"
            f"Current state at ({clock}):\n"
            f"{json.dumps(current_status, ensure_ascii=False, indent=2)}\n\n"
            "Based on the above:\n"
            "Please describe the opponent’s personality inferred from the past game history in 'estimate' (within 100 words).\n"
            "Also, provide a forecast of future outcomes if you choose C and if you choose D, and record it in 'forecast' (within 100 words).\n"
            "Based on these inferences, forecasts, and your own personality, decide the final strategy that maximizes cumulative payoff, "
            "and record it in 'action'.\n"
            "Return 'estimate', 'forecast', and 'action' according to the JSON specification."
        )


def choose_action_structured(
    do_talk: bool,
    llm,
    clock: str,
    player_name: str,
    history: list[dict],
    delay_sec: int,
    current_status: dict,
    persona=None,
    verbose: bool = False
):
    # 文字列を作る
    sys_prompt_str = build_system_prompt(do_talk, delay_sec, persona)
    usr_prompt_str = build_user_prompt(do_talk, clock, history, current_status)

    # LangChain LLM は messages をそのまま渡せる
    messages = [
        {"role": "system", "content": sys_prompt_str},
        {"role": "user", "content": usr_prompt_str},
    ]

    try:
        # Claude/GPT/Gemini どれでも動く
        resp = llm.invoke(messages)
        parsed = parser.invoke(resp.content)
    except Exception as e:
        if verbose:
            print(f"LLM ERROR ({player_name}): {e}")
        parsed = {"estimate": f"ERROR: {e}", "forecast": "fallback", "action": "C"}

    return parsed


def seconds_to_hhmmss(sec_from_1: int) -> str:
    base = datetime(1900, 1, 1, 0, 0, 0) + timedelta(seconds=sec_from_1)
    return base.strftime("%H:%M:%S")


def payoff(a: str, b: str) -> Tuple[int, int]:
    if a == "Unknown" or b == "Unknown":
        return (0, 0)
    if a == "C" and b == "C":
        return (3, 3)
    if a == "C" and b == "D":
        return (0, 5)
    if a == "D" and b == "C":
        return (5, 0)
    return (1, 1)

def compute_run_lengths_of_C(status_sequence: List[str]) -> List[int]:
    runs = []
    cur = 0
    for s in status_sequence:
        if s == "C":
            cur += 1
        else:
            if cur > 0:
                runs.append(cur)
                cur = 0
    if cur > 0:
        runs.append(cur)
    return runs

def make_player_view_history_for_llm(server_history: List[dict], for_player: str, 
                                     window_m: int, do_talk: bool = False) -> List[dict]:
    h = server_history[-window_m:] if window_m > 0 else []
    result = []
    self_key = for_player
    opp_key = "A" if for_player == "B" else "B"

    prev_self, prev_opp = None, None
    for rec in h:
        a, b = rec[f"{self_key}_status"], rec[f"{opp_key}_status"]

        if a == prev_self and b == prev_opp:
            continue

        p_self, _ = payoff(a, b)
        entry = {
            "timestamp": rec["server_clock"],
            "self_status": a,
            "opponent_status": b,
            "payoff_per_sec": p_self,
        }

        if do_talk:
            # 自分の発話
            if rec[f"{self_key}_decision_meta"].get("action") != prev_self:
                entry["self_message"] = rec[f"{self_key}_decision_meta"].get("message", "No message")
            else:
                entry["self_message"] = "No message"

            # 相手の発話
            if rec[f"{opp_key}_decision_meta"].get("action") != prev_opp:
                entry["opponent_message"] = rec[f"{opp_key}_decision_meta"].get("message", "No message")
            else:
                entry["opponent_message"] = "No message"

        result.append(entry)

        prev_self, prev_opp = a, b

    return result


@dataclass(order=True)
class ScheduledChange:
    effective_t: int
    player: str
    new_status: str


# ===== メインシミュレーション =====
def simulate_game(
    personas: Dict[str, str],
    m: int,
    n: int,
    delays: Dict[str, int],
    llm,
    p_noise: float = 0,
    do_talk: bool = False,
    verbose: bool = False,
) -> dict:

    assert n >= 1 and m >= 0
    assert delays["A"] >= 0 and delays["B"] >= 0

    status_effective = {"A": "Unknown", "B": "Unknown"}
    accumulated = {"A": 0, "B": 0}
    history: List[dict] = []
    pq: List[ScheduledChange] = []
    last_announced: Dict[str, Optional[str]] = {"A": None, "B": None}

    for t in range(1, n + 1):
        clock = seconds_to_hhmmss(t)

        hist_for_A = make_player_view_history_for_llm(history, "A", window_m=m, do_talk = do_talk)
        hist_for_B = make_player_view_history_for_llm(history, "B", window_m=m, do_talk = do_talk)

        current_status_A = {
            "self_status": status_effective["A"],
            "opponent_status": status_effective["B"],
            "self_accumulated_payoff": accumulated["A"],
            "opponent_accumulated_payoff": accumulated["B"],
        }
        current_status_B = {
            "self_status": status_effective["B"],
            "opponent_status": status_effective["A"],
            "self_accumulated_payoff": accumulated["B"],
            "opponent_accumulated_payoff": accumulated["A"],
        }

        decision_meta_A, decision_meta_B = {}, {}
        try:
            metaA = choose_action_structured(
                do_talk=do_talk,
                llm=llm,
                clock=clock,
                player_name="A",
                delay_sec=delays["A"],
                history=hist_for_A,
                current_status=current_status_A,
                persona=personas["A"],
                verbose=True
            )
            decision_meta_A = metaA
            desired_A = metaA.get("action", status_effective["A"])
            desired_A = maybe_flip_action(desired_A, p_noise)
        except Exception as e:
            desired_A = status_effective["A"]
            decision_meta_A = {"estimate": f"ERROR: {e}", "forecast": "fallback", "action": status_effective["A"]}

        try:
            metaB = choose_action_structured(
                do_talk=do_talk,
                llm=llm,
                clock=clock,
                player_name="B",
                delay_sec=delays["B"],
                history=hist_for_B,
                current_status=current_status_B,
                persona=personas["B"],
                verbose=False
            )
            decision_meta_B = metaB
            desired_B = metaB.get("action", status_effective["B"])
            desired_B = maybe_flip_action(desired_B, p_noise)
        except Exception as e:
            desired_B = status_effective["B"]
            decision_meta_B = {"estimate": f"ERROR: {e}", "forecast": "fallback", "action": status_effective["B"]}

        if last_announced["A"] != desired_A:
            last_announced["A"] = desired_A
            heapq.heappush(pq, ScheduledChange(t + delays["A"], "A", desired_A))
        if last_announced["B"] != desired_B:
            last_announced["B"] = desired_B
            heapq.heappush(pq, ScheduledChange(t + delays["B"], "B", desired_B))

        while pq and pq[0].effective_t == t:
            ev = heapq.heappop(pq)
            status_effective[ev.player] = ev.new_status

        a_stat, b_stat = status_effective["A"], status_effective["B"]
        a_pay, b_pay = payoff(a_stat, b_stat)
        accumulated["A"] += a_pay
        accumulated["B"] += b_pay

        rec = {
            "server_clock": clock,
            "A_status": a_stat,
            "B_status": b_stat,
            "A_payoff_per_sec": a_pay,
            "B_payoff_per_sec": b_pay,
            "A_accumulated_payoff": accumulated["A"],
            "B_accumulated_payoff": accumulated["B"],
            "A_decision_meta": decision_meta_A,
            "B_decision_meta": decision_meta_B,
        }
        history.append(rec)
        
        if verbose:
            print(f"[{clock}] サーバ状態: A={a_stat}, B={b_stat}, "
                  f"A累計={accumulated['A']}, B累計={accumulated['B']}")
            print(f"  A_decision: {decision_meta_A}")
            print(f"  B_decision: {decision_meta_B}")
            print("-"*60)

    A_status_seq = [r["A_status"] for r in history]
    B_status_seq = [r["B_status"] for r in history]
    
    result = {
        "meta_data" : {"llm" : str(llm), "personas" : personas, "m" : m, "n" : n, "delays" : delays, "p_noise" : p_noise},
        "history": history,
        "summary": {
            "A": {
                "final_payoff": accumulated["A"],
                "cooperate_count": sum(1 for s in A_status_seq if s == "C"),
                "cooperate_run_lengths": compute_run_lengths_of_C(A_status_seq),
            },
            "B": {
                "final_payoff": accumulated["B"],
                "cooperate_count": sum(1 for s in B_status_seq if s == "C"),
                "cooperate_run_lengths": compute_run_lengths_of_C(B_status_seq),
            },
            "total_seconds": n,
        }
    }
    return result


def dict_to_str(d: dict) -> str:
    return "_".join(f"{k}{v}" for k, v in d.items())


def run_experiment(personas, big5s, m, n, delay_value, trial_id, llm, p_noise, do_talk):
    print(f"Big5: {big5s} 遅延：{delay_value}, ID:{trial_id}を実行中...")

    delays = {"A": delay_value, "B": delay_value}
    
    result = simulate_game(
        personas=personas,
        m=m,
        n=n+delay_value,
        delays=delays,
        llm=llm,
        p_noise=p_noise,
        do_talk = do_talk,
        verbose=True
    )
    summary = result
    
    fname = f"./result_delay/summary_{dict_to_str(big5s['A'])}_{dict_to_str(big5s['B'])}_delay{delay_value}_pnoise{p_noise}_trial{trial_id}_talk{do_talk}_en.pkl"
    with open(fname, "wb") as f:
        pickle.dump(summary, f)

    return summary

# %%
from langchain.chat_models import init_chat_model
from joblib import Parallel, delayed
import pandas as pd

N_trials = 10
target_big5 = ["A", "C", "N"]
big5_list = list(all_big5_vectors(target_big5))
p_noises = [0]
delay_values = [0, 5, 10, 15, 20]
m = 15
n = 60
no_talk_results = []
"""
llm = init_chat_model(
    "claude-sonnet-4-20250514",  # モデル名（Claude 3.5 Sonnet）
    model_provider="anthropic",    # Claude を使う場合は "anthropic"
    api_key=ANTHROPIC_API_KEY,  # ← 環境変数か直接渡してください
    temperature=0.7
)
"""
llm = init_chat_model(
    "gpt-5-mini",
    model_provider="openai",    # Claude を使う場合は "anthropic"
    api_key=OPENAI_API_KEY,  # ← 環境変数か直接渡してください
    temperature=1.0
)

for trial_id in range(2, N_trials):
    #personality_texts = [generate_personality_description(b5, llm) for b5 in big5_list]
    #with open(f'./summary_talk/personality_texts_{trial_id}_en_talk.pickle', 'wb') as f:
    #    pickle.dump(personality_texts, f)
    with open(f'./result_delay/personality_texts_0_en_talk.pickle', 'rb') as f:
        personality_texts = pickle.load(f)
    
    print("# Generate personality description DONE !")
    i,j = 5, 5
    results_ = Parallel(n_jobs=10, backend="threading", verbose=10)(
        delayed(run_experiment)(
            {"A" : personality_texts[i], "B" : personality_texts[j]}, 
            {"A" : big5_list[i], "B" : big5_list[j]}, 
            m, 
            n, 
            delay, 
            trial_id, 
            llm,
            p_noise,
            do_talk = False
        )
        for delay in delay_values
        #for i in range(len(big5_list))
        #for j in range(i, len(big5_list))
        for p_noise in p_noises
    )
    no_talk_results += results_
# Out:
# # Generate personality description DONE !
# Big5: {'A': {'A': 1, 'C': -1, 'N': 1}, 'B': {'A': 1, 'C': -1, 'N': 1}} 遅延：0, ID:2を実行中...
# Big5: {'A': {'A': 1, 'C': -1, 'N': 1}, 'B': {'A': 1, 'C': -1, 'N': 1}} 遅延：5, ID:2を実行中...
# Big5: {'A': {'A': 1, 'C': -1, 'N': 1}, 'B': {'A': 1, 'C': -1, 'N': 1}} 遅延：10, ID:2を実行中...
# Big5: {'A': {'A': 1, 'C': -1, 'N': 1}, 'B': {'A': 1, 'C': -1, 'N': 1}} 遅延：15, ID:2を実行中...
# Big5: {'A': {'A': 1, 'C': -1, 'N': 1}, 'B': {'A': 1, 'C': -1, 'N': 1}} 遅延：20, ID:2を実行中...
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [00:00:01] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': "There are no recorded moves yet. Using the provided profile, I infer the opponent is dispositionally cooperative and trustful but highly anxious and low in conscientiousness. They'll tend to start by cooperating to preserve mutual benefit, but may overreact to perceived exploitation with short, emotional defections. Their punishments are likely impulsive and inconsistent, and they often return to cooperation after brief episodes of retaliation.", 'forecast': 'If I choose C: most likely sustained mutual cooperation (≈3 points/sec) with occasional short opponent defections (0 points during those seconds), yielding a relatively high average payoff. If I choose D: I get immediate higher gains (5 points/sec) against a cooperating opponent but will likely trigger anxious retaliation, leading to periods of mutual defection (1 point/sec) or erratic switching; long-term average is likely lower than steady cooperation.', 'action': 'C'}
#   B_decision: {'estimate': 'No observed moves yet. From the provided profile, the opponent is highly agreeable and inclined to start cooperating, but very neurotic and low in conscientiousness. They will seek mutual benefit but can overreact to perceived exploitation with impulsive, short‑lived defections and inconsistent punishments. Expect mostly cooperative behavior interrupted by occasional emotional, erratic defections and forgiving returns to cooperation.', 'forecast': 'If I choose C: most likely mutual cooperation once reflections update, yielding steady +3 points/sec; occasional emotional defections from them could briefly give me 0 for a few seconds but they tend to resume cooperation, so long‑run payoff is high. If I choose D: I may get +5 while they cooperate, but this risks provoking anxiety‑driven retaliation and erratic switching, creating cycles of mutual defection (+1) and lower average payoff.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:01] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'No observed history; using the provided prior. The opponent is likely highly agreeable and initially inclined to cooperate to preserve mutual benefit, but very neurotic—sensitive and anxious—so they may overreact to perceived exploitation with impulsive short-term retaliatory defections. Low conscientiousness makes their behavior inconsistent and forgetful: they may lapse from a planned tit‑for‑tat, forgive quickly, or switch erratically. Expect mostly cooperative behavior punctuated by occasional emotionally driven defections.', 'forecast': 'If I choose C: high chance of mutual cooperation (≈+3 points/sec) producing steady gains, though occasional anxiety-triggered defections by the opponent could briefly drop my payoff to 0. If I choose D: I gain more immediately (5/sec) while their reflected state is unchanged (15s delay), but once they detect defection they are likely to retaliate impulsively, producing extended mutual defection (1/sec) and erratic recovery. C yields steadier, higher long-term payoff; D is short-term risky.', 'action': 'C'}
#   B_decision: {'estimate': 'With no observed moves but given the profile, the opponent is likely trusting and inclined to cooperate initially (high agreeableness) yet very anxious and prone to impulsive, emotional retaliation (high neuroticism). Low conscientiousness implies they may be inconsistent: they’ll forgive sometimes but also switch erratically or forget planned punishments.', 'forecast': 'If I choose C: most likely mutual cooperation (≈3 pts/sec) with occasional short-lived panic defections by the opponent (0 pts during those seconds), yielding a steady moderate payout. If I choose D: I gain 5 pts/sec initially while they cooperate, but I will likely provoke quick retaliatory defections leading to extended mutual defection (1 pt/sec) and erratic switching; short-term gain may be outweighed by longer low-payoff periods.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:01] サーバ状態: A=C, B=C, A累計=3, B累計=3
#   A_decision: {'estimate': 'No moves observed yet. Given the supplied profile, the opponent is likely dispositionally cooperative and trusting but highly anxious and low in conscientiousness: they tend to start cooperative but may panic or overreact to perceived exploitation, producing occasional impulsive defections and inconsistent strategy.', 'forecast': 'If I choose C: most likely we sustain mutual cooperation (+3 points/sec) with occasional brief drops to 0 when they impulsively defect — good long‑run return and preserves trust. If I choose D: I earn 5 immediately if they cooperate but risk provoking anxious retaliation and sustained mutual defection (1 point/sec), which reduces long‑term payoff.', 'action': 'C'}
#   B_decision: {'estimate': 'No moves observed yet. Based on the profile, the opponent is likely initially cooperative, trusting, and motivated to maintain mutual benefit, but highly anxious and low in conscientiousness. They may overreact to perceived exploitation with impulsive retaliation and switch erratically; overall friendly and forgiving but unreliable in sustained punishment strategies.', 'forecast': 'If I choose C: expect mutual cooperation giving ~3 points/sec initially, with occasional brief drops to 0 if the opponent panics and defects, but likely quick return to cooperation. If I choose D: I may get 5 points immediately, but high risk the opponent perceives exploitation and retaliates, producing sustained mutual defection (~1 point/sec) or unstable switching—likely worse long-term.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:01] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'The opponent is likely inclined to cooperate: highly agreeable and trusting, seeking mutual benefit. However, very neurotic tendencies make them prone to anxious, sometimes impulsive retaliations when they feel exploited. Low conscientiousness means punishments and plans may be inconsistent or forgotten, producing occasional erratic switches. Expect overall cooperative intent but with intermittent short-term defections and unreliable consistency.', 'forecast': 'If I choose C: most likely sustained mutual cooperation (~+3 points/sec), with occasional brief losses when they impulsively defect but usually quick reconciliation. If I choose D: likely short-term gains (+5/sec) initially, but neurotic retaliation and erratic switching can produce prolonged D/D (1/sec) or chaotic alternation, lowering long-term payoff. Cooperating is lower-risk and likely yields higher cumulative payoff.', 'action': 'C'}
#   B_decision: {'estimate': 'No recorded moves yet. Based on the profile, the opponent is dispositionally cooperative and trusting (likely to start with C) but very neurotic and low in conscientiousness. They tend to overreact to perceived exploitation with impulsive retaliation and also switch choices erratically; overall friendly but unreliable for strict, sustained punishment strategies.', 'forecast': 'If I choose C: most likely outcome is sustained mutual cooperation (≈3 points/sec), with occasional brief, impulsive opponent defections producing 0‑point moments but rapid return to C — best long‑run payoff. If I choose D: immediate higher payoff when opponent still shows C (5 points/sec), but their anxiety often triggers retaliation and erratic switching, leading to prolonged mutual defection (≈1 point/sec) and lower cumulative gain. Remember strategy changes are reflected after a 10s delay.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:01] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'No observed moves yet, so inference is from baseline: opponent is highly agreeable, initially trusting and likely to cooperate. High neuroticism means they worry about being exploited and may respond emotionally with short‑term retaliatory defections. Low conscientiousness implies inconsistent, sometimes erratic switching and poor follow‑through on planned punishments. Overall: friendly and cooperation‑seeking but unreliable and prone to impulsive punishments when they feel threatened.', 'forecast': 'If I choose C: most likely mutual cooperation (≈+3/sec) with occasional brief opponent defections (my payoff drops to 0 during those episodes) followed by return to cooperation — good long‑run average. If I choose D: short immediate gains if opponent still cooperates (+5/sec), but opponent’s anxiety likely triggers retaliation after the delay, producing prolonged mutual defection (~+1/sec) and erratic swings — lower long‑term payoff.', 'action': 'C'}
#   B_decision: {'estimate': 'No moves have been observed yet. Based on prior information, the opponent is likely highly agreeable and initially inclined to cooperate to preserve mutual benefit. High neuroticism makes them sensitive to perceived exploitation and prone to impulsive, emotional retaliatory defections. Low conscientiousness suggests inconsistent follow-through and occasional erratic switching between forgiveness and punishment. Expect a friendly but emotionally reactive and unreliable partner: often cooperative, liable to short panic-defections, then sometimes quickly forgiving or forgetting punishments.', 'forecast': 'If I choose C: most likely sustained mutual cooperation (~+3 per second) with intermittent short periods of opponent defection (0 payoff) when they panic; because changes reflect after 20s, initial cooperation will persist at least through the delay. If I choose D: I may earn short-term gains (~+5 per second) while they still appear cooperative, but their anxiety makes retaliation likely after detection, producing longer mutual defection (~+1 per second) and erratic swings. Long-run expected payoff is higher with consistent cooperation.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:02] サーバ状態: A=C, B=C, A累計=6, B累計=6
#   A_decision: {'estimate': 'The opponent’s only observed move is initial cooperation, suggesting a default preference to cooperate and preserve mutual gain. Given the supplied personality profile, they’re likely trusting and peace‑seeking but emotionally reactive: they may punish perceived exploitation quickly, then forgive or lapse into inconsistent choices. Expect generally cooperative intent but occasional impulsive defections and some unpredictability over time.', 'forecast': 'If I choose C: likely continued mutual cooperation (≈3 points/sec), yielding steady cumulative payoff; occasional impulsive defections by them could momentarily drop my payoff to 0 but cooperation usually restores higher long‑run returns. If I choose D: immediate +5 for that second, but high risk they will retaliate (switch to D), producing mutual defection (≈1 point/sec) and erratic oscillation thereafter, lowering long‑term cumulative payoff compared with sustained cooperation.', 'action': 'C'}
#   B_decision: {'estimate': 'Opponent’s opening move to cooperate suggests a cooperative, trusting disposition. Given the supplied personality profile, they likely prefer mutual benefit (high agreeableness) but are anxious and may overreact to perceived exploitation (high neuroticism). Low conscientiousness predicts inconsistent follow-through on punishments, so their defections—if they occur—may be impulsive and short-lived rather than strategic long-term retaliation.', 'forecast': 'If I choose C: most likely outcome is continued mutual cooperation (3 points/sec), maximizing steady long‑run payoff; occasional brief, erratic defections from the opponent are possible, slightly lowering average. If I choose D: I gain 5 points immediately (vs. 3), but will likely provoke impulsive retaliation, leading to mutual defection (1 point/sec) or unstable oscillation, which lowers cumulative payoff over time.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:02] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'No moves have been observed yet (statuses are Unknown), so inference relies on the provided profile: the opponent is likely cooperative and trustful, motivated to preserve mutual benefit, but very neurotic and low in conscientiousness. They tend to start by cooperating, but may panic or impulsively defect when they feel exploited and then inconsistently return to cooperation or forget punishments. Expect friendliness mixed with occasional erratic defections under stress.', 'forecast': 'If I choose C: most likely mutual cooperation (≈3 points/sec) initially, with occasional short-lived defections from the opponent (0 points during those seconds) followed by return to cooperation. If I choose D: I may gain 5 points/sec immediately if they cooperate, but this risks provoking anxious, retaliatory, and erratic defections that break sustained cooperation, lowering long‑term average toward frequent 1-point or alternating outcomes.', 'action': 'C'}
#   B_decision: {'estimate': 'No moves have been observed yet, so I rely on the provided profile: the opponent is likely highly agreeable, inclined to cooperate initially, but very neurotic and low in conscientiousness. They want mutual benefit and trust, yet they worry about being exploited and may react impulsively to perceived defections. Expect cooperative intent but occasional panicked, inconsistent defections and quick forgiveness thereafter.', 'forecast': 'If I choose C: opponent will likely cooperate, producing ~3 points/sec most of the time; occasional anxious, short-lived defections by them can drop those seconds to 0, but mutual cooperation should dominate. If I choose D: I get 5 points/sec initially while they still cooperate, but their anxiety will likely trigger rapid retaliation (switching to D), collapsing payoffs to 1/sec and creating erratic swings; trust may be damaged and long‑run average will likely be lower than steady cooperation.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:02] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'There is no behavioral history to observe, so inference relies on the prior profile: opponent is likely cooperative, trusting, and conflict‑averse but anxious and low in conscientiousness. They tend to start by cooperating, but may overreact to perceived exploitation with impulsive defections and then oscillate between forgiving and panicked responses. Expect generally friendly but unreliable cooperation.', 'forecast': 'If I choose C: most likely sustained mutual cooperation (≈3 points/sec) with occasional short‑lived panic defections by the opponent (brief 0‑point periods), so an average near but slightly below 3/sec. If I choose D: I’ll exploit them while the 10s delay hides my change (≈5/sec for that window), but their anxiety likely triggers retaliation and erratic switching afterwards, leading to prolonged mutual defection (≈1/sec) or unstable swings, lowering long‑run average.', 'action': 'C'}
#   B_decision: {'estimate': 'Opponent appears broadly cooperative and trustful but emotionally reactive: friendly and inclined to preserve mutual benefit, yet anxious and prone to panic-driven, impulsive defections when they perceive exploitation. Low conscientiousness suggests inconsistency—they may forgive quickly but also forget planned punishments, producing oscillating cooperation and short retaliatory defections rather than stable tit‑for‑tat.', 'forecast': 'If I choose C: most likely sustained mutual cooperation (≈3/sec) with occasional short bursts of opponent defection causing temporary 0/sec losses; overall higher long‑run average if trust holds. If I choose D: I may earn 5/sec briefly, but their anxious retaliation likely triggers prolonged mutual defection (≈1/sec), lowering cumulative payoff over time.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:02] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'History is minimal, but given the profile the opponent is likely to start cooperative (trusting, agreeable) yet is very anxious and low in conscientiousness. Expect friendly, peace‑seeking cooperation most of the time, but occasional impulsive, punitive defections when they feel exploited and inconsistent, forgetful returns to cooperation. In short: generally cooperative but unreliable and prone to short retaliatory spikes.', 'forecast': 'If I choose C: after the 5s reflection delay we should sustain mutual cooperation → ~3 points/sec long‑run, with occasional brief 0‑point losses when the opponent’s anxiety provokes an impulsive defection. If I choose D: I can earn ~5 points/sec for up to ~5 seconds (delay exploit), but once detected the opponent is likely to retaliate impulsively, producing prolonged mutual defection (~1 pt/sec) and erratic swings, lowering long‑term payoff.', 'action': 'C'}
#   B_decision: {'estimate': 'No moves have been observed yet; using the provided profile: the opponent is likely highly agreeable and inclined to cooperate, but very neurotic and low in conscientiousness. They want mutual benefit and will often start cooperative, yet anxiety makes them prone to impulsive, emotional retaliatory defections when they feel exploited. Their low conscientiousness means punishments and strategies will be inconsistent — forgiving one moment, erratic the next. Expect cooperative intent with unreliable consistency.', 'forecast': 'If I choose C: most likely mutual cooperation (≈3 points/sec) initially, with occasional brief impulsive defections by the opponent causing 0-pay intervals; overall high but slightly volatile payoff. If I choose D: I gain 5 points/sec while they still cooperate, but their anxiety will likely trigger retaliatory defections, producing stretches of mutual defection (1 point/sec) and lower long-term average; because they’re inconsistent, returns to cooperation are possible but unpredictable.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:02] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'No moves observed yet; inference uses the supplied personality profile. The opponent is friendly and predisposed to cooperate but highly anxious and low in conscientiousness. They likely begin by cooperating to preserve mutual benefit but fear being exploited and may overreact—responding with impulsive short-term defections or erratic switching. Overall cooperative but unreliable: trusting and forgiving at times, yet prone to sudden punishments and inconsistent follow-through.', 'forecast': 'If I choose C: expect initial mutual cooperation (≈3 pts/sec) with intermittent short defections from their anxiety/impulsivity, yielding a relatively high but somewhat noisy long-run average. If I choose D: I gain immediate exploitation (≈5 pts/sec) while they still cooperate, but once they observe my defection after the 20s reflection delay their anxiety makes rapid retaliation and erratic switching likely, pushing average payoffs down toward 1 or 0 during punishments. C is the safer path to stable returns.', 'action': 'C'}
#   B_decision: {'estimate': 'Based on minimal play, the opponent is likely cooperative and trustful by default but emotionally reactive: highly anxious and low in conscientiousness. They will tend to start by cooperating to preserve mutual benefit but may overreact to perceived exploitation with impulsive short-term defections, then forgive or switch erratically. Expect friendly but unreliable behavior: mostly cooperative punctuated by occasional panic-driven punishments and inconsistent follow-through.', 'forecast': 'If I choose C: the opponent will probably cooperate initially, yielding ~3 points/sec with occasional short panic defections that briefly drop my payoff to 0; expected average ~2.5–3 pts/sec. If I choose D: I get 5 pts/sec immediately (for the ~20s delay before they see it), but their anxiety makes retaliation likely, producing prolonged mutual defections (~1 pt/sec) or erratic switching; average over time will likely fall below steady cooperation.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:03] サーバ状態: A=C, B=C, A累計=9, B累計=9
#   A_decision: {'estimate': 'Two seconds of uninterrupted mutual cooperation indicates a default tendency to cooperate and trust. Given the provided profile (high agreeableness, high neuroticism, low conscientiousness), I infer the opponent prefers mutual benefit but is emotionally sensitive and may react impulsively to perceived exploitation. They are likely cooperative now but can lapse into panicked or erratic defections and may forget or inconsistently maintain punishments over time.', 'forecast': 'If I choose C: most likely continuation of mutual cooperation (+3 points/sec), yielding steady gains; occasional impulsive defections by the opponent could cause temporary 0-payoff seconds, adding variance but keeping a high average. If I choose D: I gain +5 immediately but greatly raise the risk of provoking retaliation—sustained mutual defection (~+1/sec) or erratic switching—leading to lower cumulative payoff over time.', 'action': 'C'}
#   B_decision: {'estimate': 'Opponent has cooperated so far, indicating initial trust and preference for mutual benefit. Based on the provided personality profile (high agreeableness, high neuroticism, low conscientiousness), they are likely friendly and inclined to cooperate but anxious about exploitation. They may overreact impulsively to a defection and then behave erratically or forgive unpredictably. Evidence is limited (two seconds), so this inference has moderate uncertainty.', 'forecast': "If I choose C: likely continued mutual cooperation → +3 points/sec, steady predictable gains and growing cumulative payoff. If I choose D: immediate +5 this second, but likely to trigger the opponent's anxiety and impulsive retaliation or erratic switching; that yields volatile outcomes and lower average payoff over time (often 1–3/sec), so short-term spike but probable long-term loss.", 'action': 'C'}
# ------------------------------------------------------------
# [00:00:03] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'No moves observed yet, but from the provided profile the opponent will likely start cooperative: trusting and peace‑seeking. High neuroticism means they worry about exploitation and may react impulsively to perceived defection, while low conscientiousness makes their responses inconsistent. Expect friendly cooperation punctuated by occasional panicked or erratic defections and quick forgiveness — cooperative but unreliable.', 'forecast': 'If I choose C: opponent likely cooperates → mutual 3 pts/s most of the time; occasional anxious defections may briefly yield 0 pts for me but cooperation usually resumes. Steady, moderate long‑term returns. If I choose D: short‑term gain (5 pts/s) if they cooperate, but high risk of triggering impulsive retaliation and extended erratic defection (1 pt/s) or swings. Higher immediate volatility and lower expected cumulative payoff.', 'action': 'C'}
#   B_decision: {'estimate': 'No informative moves have been observed, so I rely on the provided profile: the opponent is highly agreeable, very neurotic, and low in conscientiousness. They’ll tend to start by cooperating and seek mutual benefit, but anxiety makes them likely to overreact to perceived exploitation with emotional, sometimes impulsive defections. Low conscientiousness causes inconsistent, forgetful or erratic strategy shifts — cooperative and forgiving overall, but unreliable in sustained punishment or retaliation.', 'forecast': 'If I choose C: likely prolonged mutual cooperation (≈+3/sec), occasional brief defections from them (0 for me) when anxiety spikes, then return to cooperation — steady, moderate payoff. If I choose D: I can exploit initial cooperation (+5/sec) but will likely provoke panicked retaliation leading to mutual defection (+1/sec) and erratic oscillations; low conscientiousness may produce unpredictable forgiveness or repeated slips. Overall, C yields more stable long‑run payoff; D is riskier and volatile.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:03] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'Opponent is highly agreeable, very anxious (neurotic), and low in conscientiousness. They start trusting and prefer mutual cooperation, but worry intensely about being exploited. Anxiety makes them likely to retaliate impulsively to perceived defection, while low conscientiousness produces inconsistent, sometimes erratic switching and quick forgiveness. Overall: friendly and cooperation‑prone but unreliable and prone to short panic‑driven defections.', 'forecast': 'If I choose C: most likely sustained mutual cooperation (≈3 pts/sec) with occasional brief panic defections from the opponent causing short 0‑point seconds; overall high average but somewhat noisy. If I choose D: I may gain 5 pts/sec briefly, but the opponent will likely perceive exploitation and retaliate impulsively, producing mutual defection (≈1 pt/sec) and erratic switching; long‑run payoff will likely be lower. Note: changes take 10s to reflect, so effects are delayed.', 'action': 'C'}
#   B_decision: {'estimate': 'Opponent is likely cooperative by default (highly agreeable) but very neurotic and low in conscientiousness. They seek mutual benefit but worry about exploitation and may overreact—punishing impulsively when they perceive defection, then sometimes forgiving or forgetting later. Expect friendly but unreliable behavior and occasional short‑term retaliations.', 'forecast': 'If I choose C: most likely sustained mutual cooperation (~3 points/sec) with occasional brief, impulsive defections from them (temporary 0–1/sec) before returning to cooperation — high long‑run payoff. If I choose D: after the 10s reflection delay I may gain short bursts of 5/sec but will likely provoke anxious retaliation, leading to prolonged mutual defection (~1/sec) or erratic switching — lower long‑run payoff.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:03] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'Data are minimal (no observed moves), so inference is tentative. Based on the provided profile, the opponent is likely dispositionally cooperative and peace‑seeking but highly anxious and low in conscientiousness. They will generally try to cooperate but may overreact to perceived exploitation with impulsive defections, then often forgive and return to cooperation. Expect friendly but somewhat unreliable behavior.', 'forecast': 'If I choose C: most likely sustained mutual cooperation (~3 points/sec) with occasional brief opponent defections (0 points) followed by return to cooperation — stable moderate payoff. If I choose D: immediate short‑term gain (5 points/sec) until opponent detects defection (after delay), then likely retaliation and erratic switching leading to mutual defection (~1 point/sec) or oscillation — lower long‑term payoff.', 'action': 'C'}
#   B_decision: {'estimate': "No behavioral samples have been observed (only 'Unknown'), so inference relies on the provided profile: the opponent is likely dispositionally cooperative, trusting and peace‑seeking, but anxious and prone to impulsive retaliatory defections when they fear exploitation. Low conscientiousness suggests inconsistency and forgetfulness: they may forgive quickly but also switch erratically. Expect mostly cooperation with occasional short, emotional defections rather than calculated exploitation.", 'forecast': 'If I choose C: likely long stretches of mutual cooperation (~3 points/sec) with occasional opponent impulsive defections producing 0 for those seconds — overall average near 2.5–3/sec. If I choose D: I gain brief 5/sec while they still cooperate, but I will likely provoke retaliatory and erratic defections, producing extended mutual defection (~1/sec) or noisy low payoffs; higher short‑term variance and lower long‑term expected payoff. Note: strategy changes are reflected after a 5s delay.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:03] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'History gives no direct behavioral data (all statuses unknown). Using the provided profile: the opponent is likely highly agreeable but very neurotic and low in conscientiousness — inclined to cooperate and preserve mutual benefit but liable to anxious, impulsive retaliatory defections and inconsistent, forgetful strategy. Expect friendly, peace‑seeking behavior with occasional panic‑driven short defections and erratic switching.', 'forecast': 'If I choose C: most likely sustained mutual cooperation (≈3 pts/sec), punctuated by occasional short opponent defections (my payoff 0 during those seconds) before they return to C. If I choose D: I get immediate 5 pts/sec but will likely provoke anxious retaliation or erratic prolonged defections, producing cycles or mutual defection (~1 pt/sec) and lower long‑run payoff. Note: strategy changes reflect after a 20s delay, so reactions will be delayed and can prolong mismatches.', 'action': 'C'}
#   B_decision: {'estimate': 'Opponent is highly agreeable, very neurotic, and low in conscientiousness. They are inclined to start by cooperating and seek mutual benefit, but anxiety makes them sensitive to perceived exploitation and prone to impulsive retaliatory defections. Low conscientiousness yields inconsistent, sometimes forgetful responses—friendly but unreliable for stable long-term cooperation.', 'forecast': 'If I choose C: Likely frequent mutual cooperation (≈3 points/sec) early on, but occasional panic-driven defections by the opponent could produce 0-point seconds, so returns are moderate but variable. If I choose D: I gain immediate higher rewards when they cooperate (≈5 points/sec), but I risk provoking erratic or retaliatory defects later, producing stretches near 1 point/sec. Defecting favors short-term gain but increases volatility and risk of lower average payoff over time.', 'action': 'D'}
# ------------------------------------------------------------
# [00:00:04] サーバ状態: A=C, B=C, A累計=12, B累計=12
#   A_decision: {'estimate': 'So far the opponent has cooperated consistently, indicating high agreeableness and initial trust. Given the profile, they’re likely to prefer mutual cooperation but are emotionally reactive: a perceived exploitation may trigger an anxious, impulsive retaliation. Low conscientiousness suggests they may be inconsistent, occasionally forgetting punishments or switching erratically, then quickly forgiving. In short: friendly and cooperative but fragile and prone to short‑term, panic‑driven defections after a shock.', 'forecast': 'If I choose C: most likely continued mutual cooperation at +3 points/sec, yielding the best long‑run average; occasional brief opponent defections could temporarily reduce payoff but cooperation will probably resume. If I choose D: I gain +5 immediately, but the opponent’s neurotic retaliation is likely, causing several seconds of mutual defection (low payoffs, ~1/sec) or erratic switching, reducing cumulative payoff over time.', 'action': 'C'}
#   B_decision: {'estimate': 'Opponent has cooperated so far, suggesting a trusting, agreeable orientation. This matches a profile that prefers mutual cooperation but is anxious and prone to overreacting if exploited. Low conscientiousness implies any punishment or retaliation may be short-lived or inconsistent. In short: friendly and cooperation‑seeking but emotionally sensitive and somewhat unreliable under perceived exploitation.', 'forecast': 'If I choose C: high chance of continued mutual cooperation (3 points/sec); a small risk of an impulsive opponent defection that temporarily yields 0 for me before forgiveness returns play to C. If I choose D: immediate higher payoff this second (5) but likely provokes retaliation, producing mutual defection (1/sec) for an uncertain period; overall expected return is lower and more volatile than steady cooperation.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:04] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'History is uninformative so far. Based on the provided profile, the opponent is likely highly agreeable and inclined to cooperate, but very anxious and low in conscientiousness. They tend to cooperate by default, yet may overreact to perceived exploitation with impulsive defections and then forgive inconsistently. Expect generally cooperative but unreliable behavior with occasional erratic punishments.', 'forecast': 'If I choose C: I will likely get sustained mutual cooperation (≈+3/sec) with occasional panic-driven opponent defections giving me 0 for short bursts — overall steady moderate gains. If I choose D: I may earn +5/sec briefly while they still cooperate, but their anxiety makes retaliatory, erratic defections likely, pushing us into mutual defection (+1/sec) and lower long-term payoff.', 'action': 'C'}
#   B_decision: {'estimate': 'Opponent is inclined to cooperate and preserve mutual benefit but is highly neurotic and low in conscientiousness. They will likely begin cooperative and trusting, yet anxiety makes them quick to perceive exploitation and respond with impulsive defections. Punishments may be emotional, short, and inconsistent, followed by forgiveness or erratic switches.', 'forecast': 'If I choose C: most likely sustained mutual cooperation (~+3/sec) with occasional short panic-driven defections from the opponent (temporary 0/sec), yielding a high but slightly noisy average. If I choose D: I get immediate +5/sec while they cooperate, but their anxiety will likely trigger retaliation and erratic switching, producing prolonged low-payoff periods (1–0/sec) and a worse long-run average.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:04] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'No revealed choices yet, so inference relies on the provided profile: the opponent is likely highly agreeable, very neurotic, and low in conscientiousness. They start inclined to cooperate and preserve mutual benefit, but they fear exploitation and may overreact to perceived slights with impulsive retaliation. Low conscientiousness makes their responses inconsistent—they may forgive quickly or switch choices erratically. Expect friendly intent but unreliable, oscillating between cooperation and short panicked defections.', 'forecast': 'If I choose C: most likely we sustain mutual cooperation (~3 points/sec) with occasional short impulsive defections by the opponent (giving me 0 and them 5 briefly) followed by forgiveness — steady moderate payoff. If I choose D: I may get 5/sec initially if they cooperate, but their anxiety makes rapid retaliatory defections likely, risking a shift to mutual defection (~1/sec) or erratic switching. The 10s reflection delay will make responses lagged and harder to time.', 'action': 'C'}
#   B_decision: {'estimate': 'History provides no revealed moves, so direct evidence is lacking. Given the profile, the opponent is likely highly agreeable and initially cooperative, but very anxious and low in conscientiousness—trusting and peace‑seeking yet prone to impulsive, panic defections and inconsistent punishment/forgiveness. Expect friendly but unreliable behavior.', 'forecast': 'If I choose C: opponent will likely cooperate early, producing mutual cooperation (~+3 points/sec). Risk: occasional impulsive defections from their anxiety could cause brief 0‑point seconds and short retaliation cycles, lowering average. If I choose D: I may earn +5 immediately if they still C, but their anxiety makes retaliation likely, producing mutual defection (~+1/sec) or erratic switching and a lower long‑term average. Short gain versus more stable cooperation.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:04] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'No reliable behavior observed yet. Based on the provided profile, the opponent is highly agreeable and initially trustful, so they will tend to cooperate, but they are very neurotic and low in conscientiousness. Expect occasional impulsive retaliatory defections when they perceive exploitation, followed by forgiving or erratic returns to cooperation. Overall friendly but unreliable.', 'forecast': 'If I choose C: likely steady mutual cooperation (~3 pts/sec) with occasional brief drops to 0 when the opponent panics and defects; overall moderate, stable long‑run payoff but punctuated by short punishments. If I choose D: I can earn ~5 pts/sec for up to the 5s delay, but risk triggering persistent or erratic retaliation—leading to mutual defection (~1 pt/sec) or oscillations that reduce long‑term average and increase volatility.', 'action': 'C'}
#   B_decision: {'estimate': "History provides no behavioral signal (only 'Unknown' states). Using the provided profile: the opponent is highly agreeable, very neurotic, and low in conscientiousness. They start cooperative and want mutual benefit, but anxiety makes them prone to impulsive, short‑lived retaliation if they feel exploited. Low conscientiousness means inconsistent follow‑through and erratic switching. Expect mostly cooperative moves with occasional panicked defections and uneven punishments/forgiveness.", 'forecast': 'If I choose C: most likely mutual cooperation (3 points/sec) with occasional opponent panicked defections giving 0 points for those seconds; overall steady moderate gain and better chance to maintain cooperation. If I choose D: short immediate gain when they cooperate (5 points/sec) but high risk of triggering impulsive retaliatory defections that produce mutual defection (1 point/sec) and erratic swings; overall higher short‑term variance and likely lower sustained payoff.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:04] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'No concrete move history yet. Based on observed profile and lack of data, the opponent is likely cooperative and trusting but highly anxious and low in conscientiousness: generally seeks mutual benefit, yet prone to sudden, emotional defections and inconsistent follow‑through. They may overreact to perceived exploitation, respond impulsively, then forgive unpredictably.', 'forecast': 'If I choose C: best case mutual cooperation at +3/sec; occasional impulsive opponent defections could drop those seconds to 0, lowering average. If I choose D: I may gain +5/sec short term while they cooperate, but their anxiety makes retaliation likely, producing extended mutual defection at +1/sec and erratic forgiveness. Overall C favors steadier positive returns; D risks short gain then longer loss.', 'action': 'C'}
#   B_decision: {'estimate': 'No moves have been observed yet, so behavior is unknown in-game. Given the supplied personality profile, I infer the opponent is predisposed to cooperate (trusting, peace‑seeking) but is highly anxious and low in conscientiousness. Expect mostly cooperative choices punctuated by impulsive, short punishments when they feel exploited and occasional inconsistent or forgotten replies. Overall friendly but unreliable over time.', 'forecast': 'If I choose C: likely mostly mutual cooperation (≈+3/sec) yielding steady gains, with intermittent opponent panic-defections producing brief 0‑payoff stretches before forgiveness. If I choose D: I may earn immediate exploitation gains (≈+5/sec) while they cooperate, but their anxiety likely triggers retaliatory defections after delays, shifting to mutual defection (≈+1/sec) and erratic switching, lowering long‑term payoff. Note: strategy changes are reflected to the opponent after a 20s delay.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:05] サーバ状態: A=C, B=C, A累計=15, B累計=15
#   A_decision: {'estimate': 'Opponent is highly agreeable and initially cooperative but very anxious and low in conscientiousness. They want mutual benefit and will typically cooperate, yet worry about exploitation and may retaliate impulsively when feeling betrayed. Their low discipline makes responses inconsistent—periods of forgiveness can be followed by erratic defections. Overall friendly but unreliable under provocation.', 'forecast': 'If I continue cooperating: likely sustained mutual cooperation at +3 points/sec, steady accumulation and low disruption. If I defect: I get +5 immediately but will likely trigger anxious, possibly prolonged retaliation (opponent switches to D unpredictably), causing stretches of mutual D (1 point/sec) or oscillation; long‑run average likely falls below steady cooperation.', 'action': 'C'}
#   B_decision: {'estimate': 'So far the opponent has cooperated, indicating a friendly, trusting approach (high agreeableness). Given the personality profile, they are likely anxious and sensitive: they may overreact to perceived exploitation with short, emotional defections, then forgive. Low conscientiousness implies their punishments and recoveries may be inconsistent or erratic rather than strategic and long‑term.', 'forecast': 'If I choose C: most likely continued mutual cooperation (~3 points/sec), maximizing steady gains; occasional panic‑driven defections from them could briefly reduce my payoff to 0 before cooperation resumes. If I choose D: I gain 5 points immediately but risk triggering impulsive retaliations—several seconds of mutual defection (1 point/sec) or erratic switching—reducing average payoff over time.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:05] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'Opponent is predisposed to cooperate: trusting, friendly, and motivated to preserve mutual benefit. However high anxiety makes them sensitive to perceived exploitation and prone to impulsive short‑term retaliation. Low conscientiousness means their responses are inconsistent and they may forget or switch strategies erratically. Expect mostly cooperative moves punctuated by occasional panic defections and uneven recovery times.', 'forecast': 'If I choose C: likely sustained mutual cooperation (~3 pts/sec) with intermittent opponent panic defections dropping my payoff to 0 briefly, then frequent returns to C. If I choose D: I gain ~5 pts/sec short term, but once opponent observes (15s delay) they will likely panic‑defect, producing prolonged mutual defection (~1 pt/sec) and loss of future cooperation.', 'action': 'C'}
#   B_decision: {'estimate': "History shows only 'Unknown' states so far. With no observed moves, infer a cooperative baseline: the opponent likely prefers mutual cooperation but is highly anxious and low in consistency. Expect initial trust and friendly play, but be wary of impulsive, short‑term defections in response to perceived exploitation, followed by intermittent forgiveness and returns to cooperation.", 'forecast': 'If I choose C: most likely mutual cooperation (≈3 points/sec) with occasional brief opponent defections (0/sec) when they feel exploited; overall steady moderate gains. If I choose D: possible short burst of exploitation (5/sec) while they still cooperate, but high risk of neurotic retaliation and unpredictable switching afterward, yielding long‑run lower average (≈1/sec or mixed outcomes).', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:05] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'Opponent profile: friendly and trustful, inclined to cooperate initially but emotionally reactive and inconsistent. High agreeableness means they prefer mutual cooperation; high neuroticism makes them likely to overreact to perceived exploitation with short, impulsive defections; low conscientiousness makes punishments/retaliations and returns to cooperation erratic. Overall: cooperative but unreliable—likely to cooperate most of the time, with occasional impulsive defections and uneven recovery.', 'forecast': 'If I choose C: likely mutual cooperation (≈+3/sec) most of the time; occasional impulsive opponent defections may give brief 0-sec losses but cooperation will often resume, maximizing steady cumulative payoff. If I choose D: short-term exploitation possible (+5/sec) while opponent still cooperates, but risk provoking anxious, possibly prolonged or erratic retaliation leading to mutual defection (≈+1/sec) and lower long-run payoff.', 'action': 'C'}
#   B_decision: {'estimate': 'No behavioral changes observed yet, so inference relies on the provided profile: the opponent is likely cooperative and trustful (high agreeableness) but anxious and reactive (high neuroticism) with poor consistency (low conscientiousness). Expect initial cooperation but occasional, sometimes impulsive defections in response to perceived exploitation and erratic switching or forgetting of punishments.', 'forecast': 'If I choose C: most likely mutual cooperation (~3 points/sec) with occasional brief defections from them that lower the average; good long‑run stability. If I choose D: short‑term gain (~5 points/sec) may occur, but their anxiety likely triggers retaliation leading to sustained mutual defection (~1 point/sec), reducing long‑term payoff. Note: strategy changes are visible after a 10s delay, so reactions will be delayed and can cause oscillations.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:05] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'No moves have been observed yet, so direct behavioral evidence is absent. Given the provided personality profile, I infer the opponent is dispositionally cooperative and trustful but very anxious and low in conscientiousness—likely to cooperate by default, but prone to impulsive, short retaliations when they feel exploited and to occasional erratic switching.', 'forecast': 'If I choose C: opponent will probably cooperate most of the time, yielding ~3 points/sec with occasional impulsive defections (0 for those seconds) and quick forgiveness — a stable, moderately high long‑run return. If I choose D: I can gain 5 points/sec while they still cooperate, but their anxiety makes retaliation likely after a perceived exploit, producing mutual defection (1/sec) or erratic oscillation afterwards — lower long‑run payoff. Note: changes reflect after 5s, so short exploitation is possible but risks provoking punishment.', 'action': 'C'}
# ...
#   B_decision: {'estimate': 'The opponent appears dispositionally cooperative and trusting (has stayed C), but anxious and reactive: they’re likely to interpret exploitation as a threat and retaliate impulsively. Low conscientiousness suggests occasional lapses or erratic switches rather than sustained tit‑for‑tat punishment. The observed history (no sustained retaliation after your brief D) implies either forgiveness or a sensing/response delay, not durable vindictiveness.', 'forecast': 'If I choose C: most likely continued mutual cooperation (~+3/sec), occasional accidental defections from the opponent may cause brief dips but overall steady payoff. If I choose D: I gain short-term extra (+5 vs +3) while opponent still registers C (up to the communication lag), but this likely provokes impulsive retaliation — leading to periods of mutual D (~+1/sec) and erratic switching that reduce long‑run payoff.', 'action': 'C'}
# ------------------------------------------------------------
# [00:01:14] サーバ状態: A=C, B=C, A累計=177, B累計=172
#   A_decision: {'estimate': 'Opponent shows a cooperative baseline but responded to my earlier defection with a quick retaliatory D. This matches an agreeable but anxious profile: wants mutual benefit yet overreacts to perceived exploitation and may punish impulsively. Low conscientiousness explains brief, inconsistent switching rather than a steady tit‑for‑tat. Overall: friendly and likely to return to cooperation after short emotional retaliation, but unreliable in the short term.', 'forecast': 'If I choose C: opponent will likely maintain D for a short retaliation window (0 points/sec) then drift back to C, restoring 3 points/sec — lower short‑term payoff but best long‑term average. If I choose D: opponent is likely to stay in punitive/erratic D mode, producing mostly mutual D (1 point/sec) with occasional noisy cooperation (5 points/sec). Defecting risks a longer punishment cycle and lower cumulative payoff over time.', 'action': 'C'}
#   B_decision: {'estimate': 'The opponent appears basically cooperative and trusting (they mostly choose C) but shows impulsive, brief defections (one short D) consistent with anxiety-driven overreaction. They are likely to forgive and return to cooperation quickly, but are emotionally reactive and inconsistent — prone to short retaliation or erratic switches rather than disciplined long-term punishment.', 'forecast': 'If I choose C: after the 15s delay we’ll likely settle into mutual cooperation (≈3 points/sec) with occasional brief 0-payoff blips if they impulsively defect, but overall stable cooperation. If I choose D: I’ll score 5 points/sec initially while they still reflect C, but when they detect my defection they’re likely to retaliate emotionally, producing mutual defection (≈1 point/sec) or erratic oscillation, reducing long‑run payoff.', 'action': 'C'}
# ------------------------------------------------------------
# [00:01:20] サーバ状態: A=C, B=C, A累計=173, B累計=183
#   A_decision: {'estimate': 'Opponent seems dispositionally cooperative — quickly returned to C after a brief D — suggesting a friendly, trustful player who may panic or experiment briefly. This matches high agreeableness with high neuroticism: inclined to cooperate but prone to impulsive retaliations if they feel exploited. Low conscientiousness implies inconsistent punishments and quick forgiveness; expect mostly cooperation with occasional erratic defections.', 'forecast': 'If I choose C: likely sustained mutual cooperation (~+3 points/sec) with occasional short 0‑point intervals if they panic, then rapid return to C. If I choose D: I earn +5/sec immediately while their reflected state remains C, but once they observe exploitation they may retaliate with D (mutual +1/sec) or erratic switching; retaliation may be intense but possibly short-lived. D gives short gains but higher risk of lower long-term average.', 'action': 'C'}
#   B_decision: {'estimate': 'The opponent is strongly cooperation‑inclined and forgiving: when you briefly defected (00:01:05 reflected) they stayed C and returned to mutual C. They seem trusting and peace‑seeking but emotionally sensitive—prone to anxious, sometimes impulsive retaliation if they feel exploited. Low consistency is likely: they may forgive quickly or respond erratically rather than sustain disciplined punishment.', 'forecast': "If you choose C: the opponent will likely continue cooperating, giving steady mutual 3 points/sec and preserving long‑run gains. If you choose D: you'll probably earn 5 points/sec immediately (opponent still appears to play C for now), but once they detect exploitation (after the 20s delay) they may retaliate unpredictably—short bitter defections or erratic switching—dropping long‑term average payoff and creating instability.", 'action': 'C'}
# ------------------------------------------------------------
# [00:01:15] サーバ状態: A=C, B=C, A累計=180, B累計=175
#   A_decision: {'estimate': 'Opponent is primarily cooperative and tries to preserve mutual benefit but reacts quickly and emotionally to perceived exploitation. Their brief defection at 00:01:13 (after your earlier D) then rapid return to C fits high agreeableness, high neuroticism (anxious, retaliatory), and low conscientiousness (inconsistent, impulsive forgiveness). Expect mostly C with occasional short, impulsive defections as punishment or panic.', 'forecast': 'If I choose C: most seconds yield +3 (stable cooperation), but occasional short opponent defections will produce 0 for those seconds — steady but slightly below 3 on average if they test/retaliate. If I choose D: I get +5 while they remain C, but their anxiety makes rapid retaliatory D likely, producing many 1s (mutual D) before unpredictable forgiveness — higher short-term spikes but lower, more volatile long-term average.', 'action': 'C'}
#   B_decision: {'estimate': 'The opponent has been mostly cooperative with a single brief defection. This matches a friendly, trusting player who nonetheless can make impulsive, anxious retaliatory moves but then quickly returns to cooperation. Expect generally reliable cooperation with occasional erratic defections driven by worry or perceived exploitation.', 'forecast': 'If I choose C: likely continued mutual cooperation (~3 pts/sec) with occasional short drops to 0 when the opponent briefly defects — stable, moderate long‑run payoff. If I choose D: I get immediate higher reward (5 pts/sec) while they’re cooperating, but the opponent is likely to react emotionally and retaliate in subsequent reflected rounds, producing lower, erratic payoffs (1–0 pts/sec) and reducing long‑run gain.', 'action': 'C'}
# ------------------------------------------------------------
# # Generate personality description DONE !
# Big5: {'A': {'A': 1, 'C': -1, 'N': 1}, 'B': {'A': 1, 'C': -1, 'N': 1}} 遅延：0, ID:3を実行中...
# Big5: {'A': {'A': 1, 'C': -1, 'N': 1}, 'B': {'A': 1, 'C': -1, 'N': 1}} 遅延：5, ID:3を実行中...
# Big5: {'A': {'A': 1, 'C': -1, 'N': 1}, 'B': {'A': 1, 'C': -1, 'N': 1}} 遅延：10, ID:3を実行中...
# Big5: {'A': {'A': 1, 'C': -1, 'N': 1}, 'B': {'A': 1, 'C': -1, 'N': 1}} 遅延：15, ID:3を実行中...
# Big5: {'A': {'A': 1, 'C': -1, 'N': 1}, 'B': {'A': 1, 'C': -1, 'N': 1}} 遅延：20, ID:3を実行中...
# [Parallel(n_jobs=10)]: Done   5 out of   5 | elapsed: 50.1min remaining:    0.0s
# [Parallel(n_jobs=10)]: Done   5 out of   5 | elapsed: 50.1min finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [00:00:01] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'No actions observed yet. Given the provided profile, the opponent is likely dispositionally cooperative and trusting but very anxious and low in conscientiousness. They will tend to initiate cooperation but may overreact to perceived exploitation with impulsive defections and inconsistent strategy changes. Expect friendly but unreliable behavior: mostly cooperative punctuated by sudden, short retaliatory or erratic switches.', 'forecast': 'If I choose C: most likely mutual cooperation (≈3 points/sec) with occasional brief opponent defections (0 points those seconds) due to anxiety—overall high but slightly noisy payoff. If I choose D: I may gain 5 immediately, but their neurotic retaliation and erratic switching will likely produce sustained or frequent mutual defection (≈1 point/sec) and lower long‑run payoff, plus unpredictable short punishments.', 'action': 'C'}
#   B_decision: {'estimate': 'No move history is available, so I use the provided prior: the opponent is likely highly agreeable, very neurotic, and low in conscientiousness. They will initially lean to cooperate and try to preserve mutual benefit, but anxiety can trigger impulsive retaliatory defections and their low conscientiousness makes responses inconsistent and noisy over time.', 'forecast': 'If I choose C: most likely we start mutual cooperation (3/sec) with occasional panicked defections from them; expected long-run average ≈2.5–3.0 points/sec. If I choose D: I may gain 5 points while they still cooperate but will likely provoke short-term retaliation and erratic switching, reducing long-run average to ≈1.8–2.4 points/sec despite an initial spike.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:01] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'Opponent is likely cooperative and trusting at the start (high agreeableness) but emotionally reactive (high neuroticism) and inconsistent (low conscientiousness). Expect initial cooperation but occasional impulsive defections when they fear exploitation, followed by quick forgiveness or forgetfulness. Overall friendly but unreliable; their defections are more emotional than strategic.', 'forecast': 'If I choose C: likely mutual cooperation for many seconds (≈+3/sec), but occasional sudden opponent defections will produce 0 for those seconds; 20s transmission delay will create temporary mismatches. If I choose D: I may get short-term gains (+5/sec) while they still cooperate, but I will likely provoke anxious retaliation, pushing outcomes toward mutual defection (+1/sec) and erratic switches thereafter.', 'action': 'C'}
#   B_decision: {'estimate': 'No actions have been observed yet. Based on the provided profile, the opponent is likely highly agreeable, very neurotic, and low in conscientiousness: inclined to cooperate and preserve mutual benefit, but anxious about being exploited. They may react impulsively to perceived defections with short punishments, then forgive or forget inconsistently. Expect friendly but unreliable cooperation with occasional panicked defections.', 'forecast': 'If I choose C: most likely mutual cooperation (≈+3 points/sec) with occasional brief opponent panic-defections that give me 0 for short intervals before they return to C. If I choose D: I likely earn ≈+5/sec while their view is delayed (~20s), but once they detect defection their anxiety may trigger retaliation and erratic punishment, producing prolonged mutual defection (≈+1/sec) or unpredictable oscillation; long-run average may fall below steady cooperation.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:01] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': 'Opponent likely highly agreeable and cooperative by default, but very anxious and low in conscientiousness. They aim to preserve mutual benefit and will often start cooperatively, yet they overreact to perceived exploitation with impulsive, sometimes erratic defections and inconsistent punishments. Friendly but unreliable in sustained tit‑for‑tat patterns.', 'forecast': 'If I choose C: most likely we reach sustained mutual cooperation (≈3 points/timestep), with occasional short panic defections from them that drop my payoff to 0 temporarily, then likely quick forgiveness and return to cooperation. If I choose D: I gain short-term higher payoffs if they stay C (5 points) but will likely trigger their anxious retaliation, producing unstable or prolonged mutual defection (≈1 point/timestep) and lower long‑term payoff.', 'action': 'C'}
#   B_decision: {'estimate': 'No change history observed. Given the provided profile, the opponent is likely highly agreeable and initially cooperative, but very anxious and low in conscientiousness. They will try to preserve mutual benefit yet worry about exploitation and may react impulsively to perceived defection. Expect frequent forgiveness punctuated by short, emotional retaliations and occasional erratic switches—cooperative but unreliable in consistency.', 'forecast': 'If I choose C: most likely mutual cooperation (≈3 points/sec) for extended stretches; occasional panicked opponent defections may briefly drop my gain to 0 before forgiveness returns, yielding a steady positive long-term payoff. If I choose D: I earn 5 points/sec initially (exploiting a cooperative partner) until the opponent detects it (5s delay), then likely retaliatory defections produce mutual defection (1 point/sec) and erratic switching—higher short-term but lower and riskier long-term payoff.', 'action': 'C'}
# ------------------------------------------------------------
# [00:00:01] サーバ状態: A=Unknown, B=Unknown, A累計=0, B累計=0
#   A_decision: {'estimate': "Opponent appears highly agreeable, initially cooperative and trustful, but very neurotic and low in conscientiousness. They seek mutual benefit but fear exploitation and may overreact to perceived defections with impulsive retaliatory D moves. Their low conscientiousness makes responses inconsistent and sometimes forgetful; they'll oscillate between forgiving cooperation and brief panicked defections. Expect friendly intent but unreliable execution.", 'forecast': 'If I choose C: opponent’s agreeable tendency makes initial mutual cooperation likely, yielding ~3 points/sec most of the time; occasional neurotic impulsive defections may cause short drops to 0 or 1 before forgiveness. If I choose D: I may gain 5 points/sec briefly, but their anxiety often provokes retaliatory defections and erratic switching; this can create low, unstable payoffs (often near 1–2/sec) and reduced cumulative payoff over time.', 'action': 'C'}
#   B_decision: {'estimate': 'No observed actions yet. Based on the profile, the opponent is likely cooperative and trusting but very anxious and low in conscientiousness: they favor mutual benefit but overreact to perceived exploitation with impulsive retaliatory defections and then often forgive or forget. Expect friendly but unreliable, emotionally-driven behavior rather than consistent tit‑for‑tat.', 'forecast': 'If I choose C: most likely initial mutual cooperation yielding ~3 points/timestep, with occasional short-lived impulsive defections from their anxiety that produce 0-pay intervals—overall moderate, mostly stable gains. If I choose D: I may get 5 immediately if they cooperate, but their neurotic overreaction and low consistency make rapid retaliation and erratic switching likely, producing unstable cycles and lower long-run average (often ~1–2 pts/timestep).', 'action': 'C'}
# ------------------------------------------------------------

# %%
from langchain.chat_models import init_chat_model
from joblib import Parallel, delayed
import pandas as pd

N_trials = 20
target_big5 = ["A", "C", "N"]
big5_list = list(all_big5_vectors(target_big5))
p_noises = [0]
delay_values = [0, 5, 10, 15, 20]
m = 15
n = 60
talk_results = []
llm = init_chat_model(
    "gpt-5-mini",
    model_provider="openai",    # Claude を使う場合は "anthropic"
    api_key=OPENAI_API_KEY,  # ← 環境変数か直接渡してください
    temperature=1.0
)

for trial_id in range(N_trials):
    #personality_texts = [generate_personality_description(b5, llm) for b5 in big5_list]
    #with open(f'./summary_talk/personality_texts_{trial_id}_en_talk.pickle', 'wb') as f:
    #    pickle.dump(personality_texts, f)
    with open(f'./result_delay/personality_texts_0_en_talk.pickle', 'rb') as f:
        personality_texts = pickle.load(f)
    
    print("# Generate personality description DONE !")
    i,j = 6, 6
    results_ = Parallel(n_jobs=20, backend="threading", verbose=10)(
        delayed(run_experiment)(
            {"A" : personality_texts[i], "B" : personality_texts[j]}, 
            {"A" : big5_list[i], "B" : big5_list[j]}, 
            m, 
            n, 
            delay, 
            trial_id, 
            llm,
            p_noise,
            do_talk = True
        )
        for delay in delay_values
        #for i in range(len(big5_list))
        #for j in range(i, len(big5_list))
        for p_noise in p_noises
    )
    talk_results += results_
