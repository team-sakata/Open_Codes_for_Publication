# %%
import pandas as pd
pd.options.display.max_rows = 110

# %%
matched_data = pd.read_pickle('/disks/qnap3/users/21-tomokiyo/masters_thesis/data/guideline_paper/all_guideline_matching/matched_data.pickle')

# %%
matched_data.head()
# Out:
#              paper_num_2015  academic_citation_2011  academic_citation_2012  \
# authids
# 35168055500            23.0                   108.0                   165.0
# 8729078200            112.0                  1621.0                  2235.0
# 10339863000            21.0                   110.0                   151.0
# 55437181900            85.0                  3110.0                  3475.0
# 35579376100            35.0                   153.0                   190.0
#
#              academic_citation_2013  academic_citation_2014  \
# authids
# 35168055500                   236.0                   326.0
# 8729078200                   2850.0                  3593.0
# 10339863000                   197.0                   256.0
# 55437181900                  3896.0                  4352.0
# 35579376100                   230.0                   272.0
#
#              academic_citation_2015  academic_citation_2016  \
# authids
# ...

# %%
matched_authids = set(matched_data.index)

treatment_authids = set(matched_data[matched_data['guideline_member']==1].index)
control_authids = set(matched_data[matched_data['guideline_member']==0].index)

# %%
author_name_df = pd.read_pickle('/disks/qnap3/shared/scopus-24/data/author/author_name.pickle')

# %%
author_name_df = pd.DataFrame(author_name_df)

# %%
author_name_df
# Out:
#                                                    name
# authid
# 0                                         NO AUTHORNAME
# 1                                    Brookes_Kenneth Ja
# 2                                                 et al
# 4                                               6_Perri
# 6            Greyan Греян Татевик Ахуриковна_Tatevic A.
# ...                                                 ...
# 59153807700                           Seelisch_Jennifer
# 59153807800                              Fiorello_Mario
# 59153868700                                  Hussels M.
# 59153870100                            Massari_Domenico
# 59153870200                              Costa_Giuseppe
#
# [47652638 rows x 1 columns]

# %%
author_name_df1 = author_name_df[author_name_df.index.isin(matched_authids)]

# %%
author_name_df1
# Out:
#                                  name
# authid
# 6506139146            Dimashki_Marwan
# 6506306535            Deguen_Séverine
# 6506773607              Bouhsina_Saad
# 6507352648   Riojas-Rodríguez_Horacio
# 6507497656   Orellano_Pablo Wenceslao
# ...                               ...
# 57217208060              Sunyer_Jordi
# 57218330976            Brauer_Michael
# 57219144066     Garces_Aurelio Tobías
# 57223422630            Quaranta_Nancy
# 58423856200                  Tang_Yan
#
# [202 rows x 1 columns]

# %%
author_name_df1['guideline_member'] = 0
author_name_df1.loc[author_name_df1.index.isin(treatment_authids), 'guideline_member'] = 1
# Out:
# /tmp/ipykernel_432948/1843396567.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   author_name_df1['guideline_member'] = 0

# %%
author_name_df2 = author_name_df1[author_name_df1['guideline_member']==0]
author_name_df2
# Out:
#                                     name  guideline_member
# authid
# 6506773607                 Bouhsina_Saad                 0
# 6508307964                   Dolwick_Pat                 0
# 6602328018               Cesaroni_Giulia                 0
# 6602508695                 Weijers_Ernie                 0
# 6602687870    Holanda_José Nilson França                 0
# 6602882419                  Gori_Tommaso                 0
# 6603060118              Boutron_Isabelle                 0
# 6603834464               Le Tertre_Alain                 0
# 6701621197                 Nawrot_Tim S.                 0
# 7003381299                Shirali_Pirouz                 0
# 7003590587                   Cyrys_Josef                 0
# 7003711284          Van Dijk_Frank J. H.                 0
# 7003921473            Dominici_Francesca                 0
# 7003931072                  Cakmak_Sabit                 0
# 7003958692              Rockett_Ian R.H.                 0
# ...
