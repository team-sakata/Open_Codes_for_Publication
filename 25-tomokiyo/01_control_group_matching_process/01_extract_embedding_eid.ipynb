# %% [markdown]
# ## Step1: Specialization Vector

# %%
## Read Scopus all embedding data

# %%
import pickle
import pandas as pd
import numpy as np

# %%
# Read embedding data of papers generated by LLM
embedding_df = pd.read_pickle('/disks/qnap3/users/21-tomokiyo/masters_thesis/data/guideline_paper/scopus/who_scopus_candidate_embedding_2011_2015.pickle')

# %%
embedding_df.head()
# Out:
#              eid         0         1         2         3         4         5  \
# 5958094  3914978  0.024877  0.020455  0.002267  0.020134  0.048890  0.063984
# 5958095  5238092  0.041480  0.018669  0.081892  0.041186  0.012121  0.005025
# 5958096  8180216  0.040118  0.046928  0.060415  0.094969 -0.002774 -0.006502
# 5958097  9250351 -0.029937  0.021202  0.024429  0.019491  0.004944 -0.018208
# 5958098  9348350  0.021746 -0.007900  0.019317  0.035626  0.018414  0.022567
#
#                 6         7         8  ...      1526      1527      1528  \
# 5958094  0.020937 -0.000780 -0.042343  ... -0.045901  0.008634 -0.002875
# 5958095  0.026687  0.009949 -0.017346  ... -0.020059  0.045917 -0.014179
# 5958096  0.014441 -0.006754 -0.025730  ... -0.038926 -0.004574 -0.028777
# 5958097  0.013135  0.047510 -0.006279  ... -0.003136  0.025258 -0.039475
# 5958098  0.012423  0.099752 -0.010647  ... -0.072455  0.014435 -0.013718
#
# ...

# %%
embedding_df.shape
# Out:
# (12237173, 1537)

# %%
embedding_eid_ls = embedding_df['eid'].tolist()

# %%
# np.save('/disks/qnap3/users/21-tomokiyo/masters_thesis/data/guideline_paper/all_guideline_matching/embedding_eid_ls.npy',embedding_eid_ls)
