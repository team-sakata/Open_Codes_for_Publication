# %% [markdown]
# ## Data set values for the paper

# %%
import pandas as pd

# %%
df_paper = pd.read_pickle('/disks/qnap3/shared/scopus-24/data/paper/eid.pickle')

# %%
df_paper.shape
# Out:
# (88226156,)

# %%
df_author = pd.read_pickle('/disks/qnap3/shared/scopus-24/data/author/author_name.pickle')

# %%
df_author.shape
# Out:
# (47652638,)

# %%
df_ov = pd.read_pickle('/disks/qnap3/shared/Overton/IGO_citation_with_scopus.pickle')

# %%
df_ov.shape
# Out:
# (6838694, 23)

# %%
df_ov.head()
# Out:
#                        Citing document identifier  \
# 0  unitednations-cd246ffa81f62cbd9f125b52825f96e5
# 1  unitednations-cd246ffa81f62cbd9f125b52825f96e5
# 2            imf-5bdb08c9d2fb5e9b0c8485b8ffe86b15
# 3        uncepal-f8e39e38314023c77029f4b3bb52553d
# 4        uncepal-f8e39e38314023c77029f4b3bb52553d
#
#      Source of citing document Source type of citing document  \
# 0               United Nations                            igo
# 1               United Nations                            igo
# 2  International Monetary Fund                            igo
# 3         United Nations CEPAL                            igo
# 4         United Nations CEPAL                            igo
#
#   Source subtype of citing document Source country of citing document  \
# 0                               NaN                               IGO
# 1                               NaN                               IGO
# 2                               NaN                               IGO
# ...

# %%
df_ov['Published on date of citing document'].sort_values()
# Out:
# 0         1970-01-13
# 1         1970-01-13
# 2         1970-03-01
# 3         1970-03-16
# 4         1970-03-16
#              ...
# 6838688   2024-08-01
# 6838689   2024-08-01
# 6838690   2024-08-01
# 6838691   2024-08-01
# 6838693   2024-08-01
# Name: Published on date of citing document, Length: 6838694, dtype: datetime64[ns]

# %%
df_ov.drop_duplicates('Citing document identifier')
# Out:
#                              Citing document identifier  \
# 0        unitednations-cd246ffa81f62cbd9f125b52825f96e5
# 2                  imf-5bdb08c9d2fb5e9b0c8485b8ffe86b15
# 3              uncepal-f8e39e38314023c77029f4b3bb52553d
# 5              uncepal-39295c6f38f37ff76fb60cc22465983f
# 6              uncepal-27d4593397aca2a545e76631665e10be
# ...                                                 ...
# 6838560  unitednations-c9716b7dbfa9999ed4801b2da9349d0f
# 6838587           iadb-697689546ca8ba5fbc0202b9e0301683
# 6838615           iadb-80c392cfd80568e2e15ed5e74807a271
# 6838657           iadb-c6257fc26447312429ef4c510d9a899b
# 6838688           iadb-762679ad1b811eaeb7b74eb7319fd23c
#
#                Source of citing document Source type of citing document  \
# 0                         United Nations                            igo
# 2            International Monetary Fund                            igo
# 3                   United Nations CEPAL                            igo
# ...
