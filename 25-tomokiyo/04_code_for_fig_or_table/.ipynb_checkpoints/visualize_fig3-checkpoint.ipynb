# %% [markdown]
# ## Code for Fig3

# %%
# check format, color and styles
import pandas as pd
import nltk
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import pyplot as plt
import scienceplots
plt.rcParams['figure.dpi'] = 300
plt.style.use(['nature']) # start with ['science'] then ['nature']. use 'notebook', 'no-latex', 'cjk-jp-font' if needed.
# https://github.com/garrettj403/SciencePlots
print(plt.rcParams['axes.prop_cycle'].by_key()['color'])


fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(9,2.5))
fig.subplots_adjust(hspace=0.1, wspace=0.4)

n = 7
x = np.linspace(0, 2*np.pi, 100)
for i in range(n):
    ax1.plot(x, np.sin(x+np.pi/n*i), label=i)
ax1.spines[['right', 'top']].set_visible(False)
ax1.tick_params(which='both', top=False, right=False)
ax1.legend(loc='upper left', bbox_to_anchor=(1,1),frameon=False)
ax1.text(0.05, 1.02, 'a', va='top', transform=ax1.transAxes, fontsize=9)


np.random.seed(0)
a = 2.5  # べき分布の指数（べき指数）
size = 10000  # データのサイズ
data = np.random.zipf(a, size)

ax2.hist(data, bins=50, log=True, edgecolor='gray')
ax2.set_xlabel('$x$')
ax2.set_ylabel('N')
ax2.spines[['right', 'top']].set_visible(False)
ax2.tick_params(which='both', top=False, right=False)
ax2.legend()
ax2.text(0.05, 1.02, 'b', va='top', transform=ax2.transAxes, fontsize=9)

bins = np.logspace(np.log10(data.min()), np.log10(data.max()), 50)
hist, bin_edges = np.histogram(data, bins=bins)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
ax3.scatter(bin_centers, hist, s=10)
ax3.set_xscale('log')  # x軸を対数スケールに設定
ax3.set_yscale('log')  # y軸を対数スケールに設定
ax3.set_xlabel('$x$')
ax3.set_ylabel('N')
ax3.spines[['right', 'top']].set_visible(False)
ax3.tick_params(which='both', top=False, right=False)
ax3.legend()
ax3.text(0.05, 1.02, 'c', va='top', transform=ax3.transAxes, fontsize=9)
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
# /tmp/ipykernel_844726/2927498568.py:38: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend()
# /tmp/ipykernel_844726/2927498568.py:51: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax3.legend()
# Text(0.05, 1.02, 'c')

# %%
authid_12 = np.load('/disks/qnap3/users/21-tomokiyo/masters_thesis/data/guideline_paper/member_data/2021/A1.2_who_guideline_development_group.npy')
authid_13 = np.load('/disks/qnap3/users/21-tomokiyo/masters_thesis/data/guideline_paper/member_data/A1.3_who_systematic_review_team_revise.npy')
authid_14 = np.load('/disks/qnap3/users/21-tomokiyo/masters_thesis/data/guideline_paper/member_data/2021/A1.4_who_external_methodologists.npy')
authid_15 = np.load('//disks/qnap3/users/21-tomokiyo/masters_thesis/data/guideline_paper/member_data/A1.5_who_external_review_team_revise.npy')


boardmember_authid = list(authid_12)+list(authid_13)+list(authid_14)+list(authid_15)

# %%
boardmember_paper_df = pd.read_pickle('/disks/qnap3/users/21-tomokiyo/masters_thesis/data/guideline_paper/all_guideline_matching/guideline_menber_paper_collab_label.pickle')

treat_paper_df = pd.read_pickle('/disks/qnap3/users/21-tomokiyo/masters_thesis/data/guideline_paper/all_guideline_matching/treat_paper_collab_label_101.pickle')

control_paper_df = pd.read_pickle('/disks/qnap3/users/21-tomokiyo/masters_thesis/data/guideline_paper/all_guideline_matching/control_paper_collab_label_101.pickle')

# %%
boardmember_paper_df.head()
# Out:
#            eid      collab  year    c2   D_score
# 0   5044234359  non_collab  2005   8.0  0.014340
# 1  11044234229  non_collab  2005  10.0 -0.000455
# 2  11144226692  non_collab  2005   9.0 -0.000582
# 3  11144235200  non_collab  2005   6.0  0.003982
# 4  11144301195  non_collab  2005   0.0  0.001083

# %%
boardmember_paper_df1 = pd.DataFrame(boardmember_paper_df.groupby(['year', 'collab']).size()).reset_index()

boardmember_paper_df1.rename(columns={0:'count'},inplace=True)

boardmember_paper_df['collab'].value_counts()
# Out:
# collab
# non_collab        12563
# 2005-15_collab     1197
# 2016-21_collab      414
# 2022-23_collab       62
# Name: count, dtype: int64

# %%
treat_paper_df1 = pd.DataFrame(treat_paper_df.groupby(['year', 'collab']).size()).reset_index()

treat_paper_df1.rename(columns={0:'count'},inplace=True)

treat_paper_df['collab'].value_counts()
# Out:
# collab
# non_collab        12567
# 2005-15_collab     1200
# 2016-21_collab      376
# 2022-23_collab       60
# Name: count, dtype: int64

# %%
control_paper_df1 = pd.DataFrame(control_paper_df.groupby(['year', 'collab']).size()).reset_index()

control_paper_df1.rename(columns={0:'count'},inplace=True)

control_paper_df['collab'].value_counts()
# Out:
# collab
# non_collab        11608
# 2005-15_collab      720
# 2016-21_collab      115
# 2022-23_collab       27
# Name: count, dtype: int64

# %%
control_paper_df1
# Out:
#     year          collab  count
# 0   2005  2005-15_collab     27
# 1   2005      non_collab    298
# 2   2006  2005-15_collab     24
# 3   2006      non_collab    369
# 4   2007  2005-15_collab     27
# 5   2007      non_collab    428
# 6   2008  2005-15_collab     29
# 7   2008      non_collab    406
# 8   2009  2005-15_collab     32
# 9   2009      non_collab    485
# 10  2010  2005-15_collab     19
# 11  2010      non_collab    477
# 12  2011  2005-15_collab     34
# 13  2011      non_collab    576
# 14  2012  2005-15_collab     34
# 15  2012      non_collab    642
# 16  2013  2005-15_collab     71
# 17  2013      non_collab    612
# 18  2014  2005-15_collab     82
# 19  2014      non_collab    676
# 20  2015  2005-15_collab     74
# 21  2015      non_collab    698
# 22  2016  2005-15_collab     49
# 23  2016  2016-21_collab     20
# 24  2016      non_collab    726
# 25  2017  2005-15_collab     58
# 26  2017  2016-21_collab     15
# 27  2017      non_collab    702
# ...

# %%
# Pivoting data to separate 'colab' categories and summing counts for stacked area plot
df = boardmember_paper_df1
df_pivot_b = df.pivot(index='year', columns='collab', values='count').fillna(0)
df_pivot_b['total'] = df_pivot_b['2005-15_collab'] + df_pivot_b['2016-21_collab'] + df_pivot_b['2022-23_collab']+df_pivot_b['non_collab']
df_pivot_b['total_collab'] = df_pivot_b['2005-15_collab'] + df_pivot_b['2016-21_collab'] + df_pivot_b['2022-23_collab']

# Pivoting data to separate 'colab' categories and summing counts for stacked area plot
df = treat_paper_df1
df_pivot_t = df.pivot(index='year', columns='collab', values='count').fillna(0)
df_pivot_t['total'] = df_pivot_t['2005-15_collab'] + df_pivot_t['2016-21_collab'] + df_pivot_t['2022-23_collab']+df_pivot_t['non_collab']
df_pivot_t['total_collab'] = df_pivot_t['2005-15_collab'] + df_pivot_t['2016-21_collab'] + df_pivot_t['2022-23_collab']


# Pivoting data to separate 'colab' categories and summing counts for stacked area plot
df = control_paper_df1
df_pivot_c = df.pivot(index='year', columns='collab', values='count').fillna(0)
df_pivot_c['total'] = df_pivot_c['2005-15_collab'] + df_pivot_c['2016-21_collab'] + df_pivot_c['2022-23_collab']+df_pivot_c['non_collab']
df_pivot_c['total_collab'] = df_pivot_c['2005-15_collab'] + df_pivot_c['2016-21_collab'] + df_pivot_c['2022-23_collab']

# %%
# df_pivot_b.to_csv('/disks/qnap3/users/21-tomokiyo/masters_thesis/source/guide_line_paper/PSM/k-neighbor/visualize/data_for_gpt/collaboration/collaboration_boardmember_for_gpt.csv')
# df_pivot_t.to_csv('/disks/qnap3/users/21-tomokiyo/masters_thesis/source/guide_line_paper/PSM/k-neighbor/visualize/data_for_gpt/collaboration/collaboration_treat_for_gpt.csv')
# df_pivot_c.to_csv('/disks/qnap3/users/21-tomokiyo/masters_thesis/source/guide_line_paper/PSM/k-neighbor/visualize/data_for_gpt/collaboration/collaboration_control_for_gpt.csv')

# %%
plt.rcParams['figure.dpi'] = 600
fig, axs = plt.subplots(2, 2, figsize=(10, 5))  # axsは2×3の配列
# 配列を1次元に変換（アンパックしやすくする）
ax1, ax2, ax3, ax4 = axs.ravel()
fig.subplots_adjust(hspace=0.2, wspace=0.15)

colors = [
    (12/255, 93/255, 165/255),    # 青
    #(0/255, 185/255, 69/255),     # 緑
    (255/255, 149/255, 0/255),    # オレンジ
    (255/255, 44/255, 0/255),     # 赤
#    (132/255, 91/255, 151/255),   # 紫
#    (71/255, 71/255, 71/255),     # 暗いグレー
    (158/255, 158/255, 158/255),  # 中間的なグレー

]

fig.align_ylabels([ax1, ax3])


ax1.stackplot(df_pivot_t.index, df_pivot_t['2005-15_collab'], df_pivot_t['2016-21_collab'],df_pivot_t['2022-23_collab'], df_pivot_t['non_collab'], labels=['2005-15_collab', '2016-21_collab', '2022-23_collab','non_collab'],colors=colors)
# ax2.plot(df_pivot_t.index, df_pivot_t['total'], label='Total', color='gray', linewidth=2, linestyle='--')
ax1.axvline(x=2016, color='black', linestyle='--', linewidth=1, label='2016')
ax1.axvline(x=2021, color='black', linestyle='--', linewidth=1, label='2021')
ax1.set_ylabel('Number of papers', fontsize=15, labelpad=8)
ax1.set_xticks([2005, 2010, 2016, 2021])
ax1.set_yticks([0, 200, 400, 600, 800, 1000, 1200])
ax1.tick_params(axis='x', labelsize=12)
ax1.tick_params(axis='y', labelsize=12)

ax1.spines[['right', 'top']].set_visible(False)
ax1.tick_params(which='both', top=False, right=False)
ax1.legend(loc='upper left', bbox_to_anchor=(0.06,1.05),frameon=False, fontsize=8.5, labels=['Pre_guideline_collab', 'During_guideline_collab', 'Post_guideline_collab', 'Non_collab'])
ax1.text(0.02, 1.0, 'a', va='top', transform=ax1.transAxes, fontsize=18, fontweight='bold')
ax1.text(0.5, 1.15, 'Treatment group(n=101)', va='top', ha='center', transform=ax1.transAxes, fontsize=15, fontweight='bold')




ax2.stackplot(df_pivot_c.index, df_pivot_c['2005-15_collab'], df_pivot_c['2016-21_collab'],df_pivot_c['2022-23_collab'], df_pivot_c['non_collab'], labels=['2005-15_collab', '2016-21_collab', '2022-23_collab','non_collab'],colors=colors)
# ax3.plot(df_pivot_c.index, df_pivot_c['total'], label='Total', color='gray', linewidth=2, linestyle='--')
ax2.axvline(x=2016, color='black', linestyle='--', linewidth=1, label='2016')
ax2.axvline(x=2021, color='black', linestyle='--', linewidth=1, label='2021')
# ax3.set_xlabel('Year')
# ax3.set_ylabel('Paper count')
ax2.set_xticks([2005, 2010, 2016, 2021])
ax2.set_yticks([0, 200, 400, 600, 800, 1000, 1200])
ax2.tick_params(axis='x', labelsize=12)
ax2.tick_params(axis='y', labelsize=12)

ax2.spines[['right', 'top']].set_visible(False)
ax2.tick_params(which='both', top=False, right=False)
# ax1.legend()
ax2.text(0.02, 1.0, 'b', va='top', transform=ax2.transAxes, fontsize=18, fontweight='bold')
ax2.text(0.5, 1.15, 'Control group(n=101)', va='top', ha='center', transform=ax2.transAxes, fontsize=15, fontweight='bold')



ax3.stackplot(df_pivot_t.index, df_pivot_t['2005-15_collab'], df_pivot_t['2016-21_collab'],df_pivot_t['2022-23_collab'], labels=['2005-15_collab', '2016-21_collab', '2022-23_collab'],colors=colors)
# ax5.plot(df_pivot_t.index, df_pivot_t['total_collab'], label='Total', color='gray', linewidth=2, linestyle='--')
ax3.axvline(x=2016, color='black', linestyle='--', linewidth=1, label='2016')
ax3.axvline(x=2021, color='black', linestyle='--', linewidth=1, label='2021')
ax3.set_xlabel('Published year', fontsize=15)
ax3.set_ylabel('Number of papers', fontsize=15, labelpad=8)

# ax5.set_ylabel('Paper count')
ax3.set_xticks([2005, 2010, 2016, 2021])
ax3.set_yticks([0, 20, 40, 60, 80, 100, 120, 140, 160])
ax3.tick_params(axis='x', labelsize=12)
ax3.tick_params(axis='y', labelsize=12)

ax3.spines[['right', 'top']].set_visible(False)
ax3.tick_params(which='both', top=False, right=False)
# ax1.legend()
ax3.text(0.02, 1.0, 'c', va='top', transform=ax3.transAxes, fontsize=18, fontweight='bold')


ax4.stackplot(df_pivot_c.index, df_pivot_c['2005-15_collab'], df_pivot_c['2016-21_collab'],df_pivot_c['2022-23_collab'], labels=['2005-15_collab', '2016-21_collab', '2022-23_collab'],colors=colors)
# ax6.plot(df_pivot_c.index, df_pivot_c['total_collab'], label='Total', color='gray', linewidth=2, linestyle='--')
ax4.axvline(x=2016, color='black', linestyle='--', linewidth=1, label='2016')
ax4.axvline(x=2021, color='black', linestyle='--', linewidth=1, label='2021')
ax4.set_xlabel('Published year', fontsize=15)
# ax6.set_ylabel('Paper count')
ax4.set_xticks([2005, 2010, 2016, 2021])
ax4.set_yticks([0, 20, 40, 60, 80, 100, 120, 140, 160])
ax4.tick_params(axis='x', labelsize=12)
ax4.tick_params(axis='y', labelsize=12)

ax4.spines[['right', 'top']].set_visible(False)
ax4.tick_params(which='both', top=False, right=False)
# ax1.legend()
ax4.text(0.02, 1.0, 'd', va='top', transform=ax4.transAxes, fontsize=18, fontweight='bold')
# Out:
# Text(0.02, 1.0, 'd')
